# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.3.0

# %%
mnist = keras.datasets.mnist

# %%
mnist
# Out:
# <module 'tensorflow.keras.datasets.mnist' from '/usr/local/lib/python3.6/dist-packages/tensorflow/keras/datasets/mnist/__init__.py'>

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_train[1]
# Out:
# 0

# %%
x_train, x_test = x_train/255., x_test/255.

# %%
# Sequential API를 활용한 모델 구성

model = keras.Sequential()  # Sequential API를 활용할 준비 끝
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(10, activation='softmax')) # 10개의 노드: 0~9일 확률

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# ...
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile : 모델 학습에 필요한 정보 설정

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습

model.fit(x_train, y_train,
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2298 - accuracy: 0.9311
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0976 - accuracy: 0.9700
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0675 - accuracy: 0.9792
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0537 - accuracy: 0.9833
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0411 - accuracy: 0.9874
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0351 - accuracy: 0.9882
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0299 - accuracy: 0.9911
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0263 - accuracy: 0.9913
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0227 - accuracy: 0.9923
# Epoch 10/10
# ...

# %%
# cifar10 데이터셋을 활용

cifar10 = keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
# Sequential API를 활용한 모델 구성

model = keras.Sequential()  # Sequential API를 활용할 준비 끝
model.add(keras.layers.Flatten(input_shape=(32, 32, 3)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(10, activation='softmax')) # 10개의 노드: 0~9일 확률

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# ...
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile : 모델 학습에 필요한 정보 설정

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습

model.fit(x_train, y_train,
          epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 7.8828 - accuracy: 0.1006
# Epoch 2/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.3030 - accuracy: 0.0965
# Epoch 3/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 3.3876 - accuracy: 0.0981
# Epoch 4/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3066 - accuracy: 0.0970
# Epoch 5/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3028 - accuracy: 0.0971
# Epoch 6/10
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3028 - accuracy: 0.0987
# Epoch 7/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.3028 - accuracy: 0.0978
# Epoch 8/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.3028 - accuracy: 0.0979
# Epoch 9/10
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.3028 - accuracy: 0.0978
# Epoch 10/10
# ...
