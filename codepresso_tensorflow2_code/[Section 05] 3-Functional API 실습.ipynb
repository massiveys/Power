# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Functional API를 활용 한 실습

# %%
# 모델 구성

inputs = keras.Input(shape=(28, 28, 1)) # Input을 선언

x = keras.layers.Flatten()(inputs)
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dense(128, activation='relu')(x)
x = keras.layers.Dropout(rate=0.2)(x)
predictions = keras.layers.Dense(10, activation='softmax')(x)

# %%
# 모델 학습

model = keras.Model(
    inputs=inputs,
    outputs=predictions
)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# mnist 데이터셋을 활용

mnist = keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train, x_test = x_train/255., x_test/255.

# %%
# model.compile : 모델 학습에 필요한 정보 설정

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습

model.fit(x_train, y_train,
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2230 - accuracy: 0.9335
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0956 - accuracy: 0.9710
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0693 - accuracy: 0.9784
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0502 - accuracy: 0.9844
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0423 - accuracy: 0.9862
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0344 - accuracy: 0.9888
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0284 - accuracy: 0.9905
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0249 - accuracy: 0.9918
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0223 - accuracy: 0.9926
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0200 - accuracy: 0.9935

# %%
# cifar10 데이터셋을 활용

cifar10 = keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train, x_test = x_train/255., x_test/255.

# %%
x_train.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
# 모델 구성

inputs = keras.Input(shape=(32, 32, 3)) # Input을 선언

x = keras.layers.Flatten()(inputs)
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dense(128, activation='relu')(x)
x = keras.layers.Dropout(rate=0.2)(x)
predictions = keras.layers.Dense(10, activation='softmax')(x)

# %%
# 모델 객체 생성

model = keras.Model(
    inputs=inputs,
    outputs=predictions
)

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               786688
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.compile : 모델 학습에 필요한 정보 설정

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습

model.fit(x_train, y_train,
          epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.9001 - accuracy: 0.3102
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.7310 - accuracy: 0.3774
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6647 - accuracy: 0.4042
# Epoch 4/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6187 - accuracy: 0.4199
# Epoch 5/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.5879 - accuracy: 0.4322
# Epoch 6/10
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.5644 - accuracy: 0.4413
# Epoch 7/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.5416 - accuracy: 0.4490
# Epoch 8/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.5286 - accuracy: 0.4516
# Epoch 9/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.5133 - accuracy: 0.4616
# Epoch 10/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.5033 - accuracy: 0.4634
